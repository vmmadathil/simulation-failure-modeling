# %% [markdown]
# # Data Exploration & Cleaning
# This notebook will contain data exploration and cleaning

# %%
#imports 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['font.size'] = 18
plt.rcParams['patch.edgecolor'] = 'k'

# %%
#reading data
sim_data = pd.read_csv('../data/raw/pop_failures.csv')
sim_data.head()
# Out:
#    Study  Run  vconst_corr  vconst_2  vconst_3  vconst_4  vconst_5  vconst_7  \
# 0      1    1     0.859036  0.927825  0.252866  0.298838  0.170521  0.735936
# 1      1    2     0.606041  0.457728  0.359448  0.306957  0.843331  0.934851
# 2      1    3     0.997600  0.373238  0.517399  0.504993  0.618903  0.605571
# 3      1    4     0.783408  0.104055  0.197533  0.421837  0.742056  0.490828
# 4      1    5     0.406250  0.513199  0.061812  0.635837  0.844798  0.441502
#
#     ah_corr  ah_bolus   ...     efficiency_factor  tidal_mix_max  \
# 0  0.428325  0.567947   ...              0.245675       0.104226
# 1  0.444572  0.828015   ...              0.616870       0.975786
# 2  0.746225  0.195928   ...              0.679355       0.803413
# 3  0.005525  0.392123   ...              0.471463       0.597879
# 4  0.191926  0.487546   ...              0.551543       0.743877
#
#    vertical_decay_scale convect_corr bckgrnd_vdc1  bckgrnd_vdc_ban  \
# ...

# %%
sim_data.dtypes
# Out:
# Study                     int64
# Run                       int64
# vconst_corr             float64
# vconst_2                float64
# vconst_3                float64
# vconst_4                float64
# vconst_5                float64
# vconst_7                float64
# ah_corr                 float64
# ah_bolus                float64
# slm_corr                float64
# efficiency_factor       float64
# tidal_mix_max           float64
# vertical_decay_scale     object
# convect_corr             object
# bckgrnd_vdc1            float64
# bckgrnd_vdc_ban         float64
# bckgrnd_vdc_eq          float64
# bckgrnd_vdc_psim        float64
# Prandtl                 float64
# outcome                   int64
# dtype: object

# %%
sim_data.dtypes.value_counts()
# Out:
# float64    16
# int64       3
# object      2
# dtype: int64

# %%
exclude = ['Study','Run']

# %%
plt.figure(figsize=(25,20))
sim_data.loc[:, sim_data.columns.difference(exclude)].boxplot()

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').hist()
# Out:
# outcome
# 0    [[AxesSubplot(0.125,0.725918;0.158163x0.154082...
# 1    [[AxesSubplot(0.125,0.725918;0.158163x0.154082...
# dtype: object

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').vconst_corr.plot(kind='kde')
plt.legend()

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').vconst_corr.hist(alpha=0.4)
# Out:
# outcome
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: vconst_corr, dtype: object

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').vconst_2.plot(kind='kde')
plt.legend()

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').vconst_2.hist(alpha=0.4)
# Out:
# outcome
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: vconst_2, dtype: object

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').vconst_3.plot(kind='kde')
plt.legend()

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').vconst_3.hist(alpha=0.4)
# Out:
# outcome
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: vconst_3, dtype: object

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').vconst_4.plot(kind='kde')
plt.legend()

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').vconst_4.hist(alpha=0.4)
# Out:
# outcome
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: vconst_4, dtype: object

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').vconst_5.plot(kind='kde')
plt.legend()

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').vconst_5.hist(alpha=0.4)
# Out:
# outcome
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: vconst_5, dtype: object

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').vconst_7.plot(kind='kde')
plt.legend()

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').vconst_7.hist(alpha=0.4)
# Out:
# outcome
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: vconst_7, dtype: object

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').ah_corr.plot(kind='kde')
plt.legend()

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').ah_corr.hist(alpha=0.4)
# Out:
# outcome
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: ah_corr, dtype: object

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').ah_bolus.plot(kind='kde')
plt.legend()

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').ah_bolus.hist(alpha=0.4)
# Out:
# outcome
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: ah_bolus, dtype: object

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').slm_corr.plot(kind='kde')
plt.legend()

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').slm_corr.hist(alpha=0.4)
# Out:
# outcome
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: slm_corr, dtype: object

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').efficiency_factor.plot(kind='kde')
plt.legend()

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').efficiency_factor.hist(alpha=0.4)
# Out:
# outcome
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: efficiency_factor, dtype: object

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').tidal_mix_max.plot(kind='kde')
plt.legend()

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').tidal_mix_max.hist(alpha=0.4)
# Out:
# outcome
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: tidal_mix_max, dtype: object

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').bckgrnd_vdc1.plot(kind='kde')
plt.legend()

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').bckgrnd_vdc1.hist(alpha=0.4)
# Out:
# outcome
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: bckgrnd_vdc1, dtype: object

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').bckgrnd_vdc1.plot(kind='kde')
plt.legend()

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').bckgrnd_vdc1.hist(alpha=0.4)
# Out:
# outcome
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: bckgrnd_vdc1, dtype: object

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').bckgrnd_vdc_ban.plot(kind='kde')
plt.legend()

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').bckgrnd_vdc_ban.hist(alpha=0.4)
# Out:
# outcome
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: bckgrnd_vdc_ban, dtype: object

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').bckgrnd_vdc_eq.plot(kind='kde')
plt.legend()

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').bckgrnd_vdc_eq.hist(alpha=0.4)
# Out:
# outcome
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: bckgrnd_vdc_eq, dtype: object

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').bckgrnd_vdc_psim.plot(kind='kde')
plt.legend()

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').bckgrnd_vdc_eq.hist(alpha=0.4)
# Out:
# outcome
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: bckgrnd_vdc_eq, dtype: object

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').Prandtl.plot(kind='kde')
plt.legend()

# %%
sim_data.loc[:, sim_data.columns.difference(exclude)].groupby('outcome').Prandtl.hist(alpha=0.4)
# Out:
# outcome
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Prandtl, dtype: object
